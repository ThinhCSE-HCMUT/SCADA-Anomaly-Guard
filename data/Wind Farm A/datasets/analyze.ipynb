# %%
import pandas as pd 
event_info_path = r"D:\Final Project\scada-fault-prediction\Dataset\raw\Wind Farm A\event_info.csv"
event_id = [] 

event_info_df = pd.read_csv(event_info_path, sep=';')
id = event_info_df['event_id'].unique()
# Out:
# <class 'numpy.ndarray'>
# [68 22 72 73  0 26 40 42 10 45 84 25 69 13 24  3 17 38 71 14 92 51]
